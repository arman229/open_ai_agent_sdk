# %%
import nest_asyncio
nest_asyncio.apply()

# %%
from dataclasses import dataclass
import asyncio
from agents.extensions.visualization import draw_graph
import os 
from openai import AsyncOpenAI 
from dotenv import load_dotenv  
load_dotenv() 
from agents import (
    Agent,
    Runner, 
    set_tracing_disabled,OpenAIChatCompletionsModel,enable_verbose_stdout_logging
)   
 

# enable_verbose_stdout_logging()
set_tracing_disabled(disabled=True)
API_KEY=os.getenv("GEMINI_API_KEY")

if  not API_KEY  :
    raise ValueError("Please set EXAMPLE_BASE_URL, EXAMPLE_API_KEY, EXAMPLE_MODEL_NAME via env var or code.")

 
client = AsyncOpenAI(base_url="https://generativelanguage.googleapis.com/v1beta/openai/",api_key=API_KEY,)

model = OpenAIChatCompletionsModel(model="gemini-2.0-flash",openai_client=client)
# Out:
# OPENAI_API_KEY is not set, skipping trace export
# OPENAI_API_KEY is not set, skipping trace export
# OPENAI_API_KEY is not set, skipping trace export
# OPENAI_API_KEY is not set, skipping trace export
# OPENAI_API_KEY is not set, skipping trace export
# OPENAI_API_KEY is not set, skipping trace export
# OPENAI_API_KEY is not set, skipping trace export

# %%
from agents import Agent, Runner, set_tracing_disabled

set_tracing_disabled(disabled=False)
agent = Agent(
    name="", # name is requried filed
    instructions="You are a helpful assistant. Your task is to respond in both Urdu and English.",
    model=model,
)

resp = await Runner.run(agent, "what is ai",max_turns=0)
print(resp.final_output)
print(dir(resp))
# Out:
# ---------------------------------------------------------------------------
# MaxTurnsExceeded                          Traceback (most recent call last)
# Cell In[8], line 10
#       3 set_tracing_disabled(disabled=False)
#       4 agent = Agent(
#       5     name="", # name is requried filed
#       6     instructions="You are a helpful assistant. Your task is to respond in both Urdu and English.",
#       7     model=model,
#       8 )
# ---> 10 resp = await Runner.run(agent, "what is ai",max_turns=0)
#      11 print(resp.final_output)
#      12 print(dir(resp))
#
# File c:\Users\arman\AppData\Local\Programs\Python\Python313\Lib\site-packages\agents\run.py:211, in Runner.run(cls, starting_agent, input, context, max_turns, hooks, run_config, previous_response_id)
#     203 if current_turn > max_turns:
#     204     _error_tracing.attach_error_to_span(
#     205         current_span,
#     206         SpanError(
#    (...)    209         ),
#     210     )
# --> 211     raise MaxTurnsExceeded(f"Max turns ({max_turns}) exceeded")
#     213 logger.debug(
#     214     f"Running agent {current_agent.name} (turn {current_turn})",
#     215 )
#     217 if current_turn == 1:
#
# MaxTurnsExceeded: Max turns (0) exceeded

# %%
print(agent.output_type
      )
# Out:
# None
