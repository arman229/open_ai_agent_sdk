# %%
import nest_asyncio
nest_asyncio.apply()

from dataclasses import dataclass
import asyncio
from agents.extensions.visualization import draw_graph
import os 
from openai import AsyncOpenAI 
from dotenv import load_dotenv  
load_dotenv() 
from agents import (
    Agent,
    Runner, 
    set_tracing_disabled,OpenAIChatCompletionsModel,enable_verbose_stdout_logging
)   
 

# enable_verbose_stdout_logging()
set_tracing_disabled(disabled=True)
API_KEY=os.getenv("GEMINI_API_KEY")

if  not API_KEY  :
    raise ValueError("Please set EXAMPLE_BASE_URL, EXAMPLE_API_KEY, EXAMPLE_MODEL_NAME via env var or code.")

 
client = AsyncOpenAI(base_url="https://generativelanguage.googleapis.com/v1beta/openai/",api_key=API_KEY,)

model = OpenAIChatCompletionsModel(model="gemini-2.0-flash",openai_client=client)
# Out:
# OPENAI_API_KEY is not set, skipping trace export
# OPENAI_API_KEY is not set, skipping trace export
# OPENAI_API_KEY is not set, skipping trace export
# OPENAI_API_KEY is not set, skipping trace export
# OPENAI_API_KEY is not set, skipping trace export
# OPENAI_API_KEY is not set, skipping trace export
# OPENAI_API_KEY is not set, skipping trace export
# OPENAI_API_KEY is not set, skipping trace export

# %%
from agents import Agent, Runner, set_tracing_disabled

set_tracing_disabled(disabled=False)
agent = Agent(
    name="basi_agent", 
    model=model,
)

# resp = await Runner.run(agent, "what is ai")
# print(resp.final_output)


print(agent.name)
# Out:
# basi_agent

# %%
from dis import Instruction


new_agent = agent.clone(name='')
resp = await Runner.run(new_agent, "what is ai")
new_resp = resp.to_input_list()
print(resp.final_output)
print(new_resp)
print(new_agent.name)
# Out:
# AI, or Artificial Intelligence, is a broad term that refers to the simulation of human intelligence processes by computer systems. These processes include learning (the acquisition of information and rules for using the information), reasoning (using rules to reach approximate or definite conclusions), and self-correction.
#
# Here's a breakdown of key aspects of AI:
#
# *   **Core Concept:** AI aims to create machines that can think and act like humans. This doesn't necessarily mean robots with human-like bodies, but rather systems that can perform tasks that typically require human intelligence.
# *   **How it Works:** AI systems generally work by analyzing large amounts of data to identify patterns, learn from those patterns, and then use that learning to make predictions or decisions.
# *   **Key Components:**
#     *   **Machine Learning (ML):** A subset of AI that allows systems to learn from data without being explicitly programmed.  Algorithms are trained on datasets to recognize patterns and make predictions.  Different types of machine learning include:
#         *   **Supervised Learning:**  Training a model on labeled data (data with known outcomes).  For example, training a model to identify pictures of cats using a dataset of images labeled as "cat" or "not cat."
#         *   **Unsupervised Learning:** Training a model on unlabeled data to find hidden patterns or structures.  For example, clustering customers into different groups based on their purchasing behavior.
#         *   **Reinforcement Learning:** Training a model to make decisions in an environment to maximize a reward.  For example, training a robot to navigate a maze by rewarding it for moving closer to the goal and penalizing it for hitting walls.
#     *   **Deep Learning (DL):** A subfield of machine learning that uses artificial neural networks with multiple layers (hence "deep") to analyze data with complex patterns. Deep learning is particularly effective for tasks like image recognition, natural language processing, and speech recognition.
#     *   **Natural Language Processing (NLP):** Enables computers to understand, interpret, and generate human language. This includes tasks like sentiment analysis, machine translation, and chatbot development.
#     *   **Computer Vision:** Enables computers to "see" and interpret images and videos. This includes tasks like object detection, facial recognition, and image classification.
#     *   **Robotics:** Combines AI with mechanical engineering to create robots that can perform physical tasks.
# *   **Types of AI:**
#     *   **Narrow or Weak AI:** Designed for a specific task (e.g., playing chess, recommending products, driving a car). This is the type of AI we mostly see today. It excels at its defined task but lacks general intelligence.
#     *   **General or Strong AI:** Possesses human-level intelligence and can perform any intellectual task that a human being can. This type of AI doesn't currently exist.
#     *   **Super AI:** An AI that surpasses human intelligence in all aspects, including creativity, problem-solving, and general wisdom.  This is a hypothetical concept.
# *   **Applications of AI:** AI is used in a wide range of industries, including:
#     *   **Healthcare:** Diagnosing diseases, personalized medicine, drug discovery.
#     *   **Finance:** Fraud detection, algorithmic trading, risk management.
#     *   **Retail:** Personalized recommendations, supply chain optimization, chatbots.
#     *   **Transportation:** Self-driving cars, route optimization, traffic management.
#     *   **Manufacturing:** Predictive maintenance, quality control, robotics.
#     *   **Entertainment:** Recommending movies and music, creating special effects, generating art.
# *   **Ethical Considerations:** AI raises important ethical questions, such as:
#     *   **Bias:** AI systems can perpetuate and amplify existing biases in the data they are trained on.
#     *   **Job displacement:** AI automation could lead to job losses in various industries.
#     *   **Privacy:** AI systems can collect and analyze vast amounts of personal data, raising privacy concerns.
#     *   **Safety:**  Ensuring the safety and reliability of AI systems, especially in critical applications like self-driving cars and medical devices.
# *   **Limitations:**
#     *   **Data Dependency:** AI systems often require massive amounts of data to train effectively.
#     *   **Lack of Common Sense:** AI systems can struggle with tasks that require common sense reasoning.
#     *   **Explainability:**  The decision-making processes of some AI systems (especially deep learning models) can be difficult to understand, making it challenging to debug and trust them.
#     *   **Creativity and Originality:**  While AI can generate creative content, it often lacks true originality and understanding of context.
#
# In summary, AI is a powerful and rapidly evolving technology that has the potential to transform many aspects of our lives.  It's important to understand its capabilities, limitations, and ethical implications to ensure that it is used responsibly and for the benefit of society.
#
# [{'content': 'what is ai', 'role': 'user'}, {'id': '__fake_id__', 'content': [{'annotations': [], 'text': 'AI, or Artificial Intelligence, is a broad term that refers to the simulation of human intelligence processes by computer systems. These processes include learning (the acquisition of information and rules for using the information), reasoning (using rules to reach approximate or definite conclusions), and self-correction.\n\nHere\'s a breakdown of key aspects of AI:\n\n*   **Core Concept:** AI aims to create machines that can think and act like humans. This doesn\'t necessarily mean robots with human-like bodies, but rather systems that can perform tasks that typically require human intelligence.\n*   **How it Works:** AI systems generally work by analyzing large amounts of data to identify patterns, learn from those patterns, and then use that learning to make predictions or decisions.\n*   **Key Components:**\n    *   **Machine Learning (ML):** A subset of AI that allows systems to learn from data without being explicitly programmed.  Algorithms are trained on datasets to recognize patterns and make predictions.  Different types of machine learning include:\n        *   **Supervised Learning:**  Training a model on labeled data (data with known outcomes).  For example, training a model to identify pictures of cats using a dataset of images labeled as "cat" or "not cat."\n        *   **Unsupervised Learning:** Training a model on unlabeled data to find hidden patterns or structures.  For example, clustering customers into different groups based on their purchasing behavior.\n        *   **Reinforcement Learning:** Training a model to make decisions in an environment to maximize a reward.  For example, training a robot to navigate a maze by rewarding it for moving closer to the goal and penalizing it for hitting walls.\n    *   **Deep Learning (DL):** A subfield of machine learning that uses artificial neural networks with multiple layers (hence "deep") to analyze data with complex patterns. Deep learning is particularly effective for tasks like image recognition, natural language processing, and speech recognition.\n    *   **Natural Language Processing (NLP):** Enables computers to understand, interpret, and generate human language. This includes tasks like sentiment analysis, machine translation, and chatbot development.\n    *   **Computer Vision:** Enables computers to "see" and interpret images and videos. This includes tasks like object detection, facial recognition, and image classification.\n    *   **Robotics:** Combines AI with mechanical engineering to create robots that can perform physical tasks.\n*   **Types of AI:**\n    *   **Narrow or Weak AI:** Designed for a specific task (e.g., playing chess, recommending products, driving a car). This is the type of AI we mostly see today. It excels at its defined task but lacks general intelligence.\n    *   **General or Strong AI:** Possesses human-level intelligence and can perform any intellectual task that a human being can. This type of AI doesn\'t currently exist.\n    *   **Super AI:** An AI that surpasses human intelligence in all aspects, including creativity, problem-solving, and general wisdom.  This is a hypothetical concept.\n*   **Applications of AI:** AI is used in a wide range of industries, including:\n    *   **Healthcare:** Diagnosing diseases, personalized medicine, drug discovery.\n    *   **Finance:** Fraud detection, algorithmic trading, risk management.\n    *   **Retail:** Personalized recommendations, supply chain optimization, chatbots.\n    *   **Transportation:** Self-driving cars, route optimization, traffic management.\n    *   **Manufacturing:** Predictive maintenance, quality control, robotics.\n    *   **Entertainment:** Recommending movies and music, creating special effects, generating art.\n*   **Ethical Considerations:** AI raises important ethical questions, such as:\n    *   **Bias:** AI systems can perpetuate and amplify exi ...

# %%
from agents import Agent

agent = Agent(
    name="weather_agent",
    instructions="You are a helpful assistant.",
    model="gpt-4o"
)

print(f"Agent name is: {agent.name}")
# Out:
# Agent name is: weather_agent
