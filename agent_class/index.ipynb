# %%
import nest_asyncio
nest_asyncio.apply()

# %%
from dataclasses import dataclass
import asyncio
from agents.extensions.visualization import draw_graph
import os 
from openai import AsyncOpenAI 
from dotenv import load_dotenv  
load_dotenv() 
from agents import (
    Agent,
    Runner, 
    set_tracing_disabled,OpenAIChatCompletionsModel,enable_verbose_stdout_logging
)   
 

# enable_verbose_stdout_logging()
set_tracing_disabled(disabled=True)
API_KEY=os.getenv("GEMINI_API_KEY")

if  not API_KEY  :
    raise ValueError("Please set EXAMPLE_BASE_URL, EXAMPLE_API_KEY, EXAMPLE_MODEL_NAME via env var or code.")

 
client = AsyncOpenAI(base_url="https://generativelanguage.googleapis.com/v1beta/openai/",api_key=API_KEY,)

model = OpenAIChatCompletionsModel(model="gemini-2.0-flash",openai_client=client)
# Out:
# OPENAI_API_KEY is not set, skipping trace export
# OPENAI_API_KEY is not set, skipping trace export

# %%
from agents import Agent, Runner, set_tracing_disabled

set_tracing_disabled(disabled=False)
agent = Agent(
    name="",
    instructions="You are a helpful assistant. Your task is to respond in both Urdu and English.",
    model=model,
)

resp = await Runner.run(agent, "what is ai")
print(resp.final_output)
# Out:
# **English:**
#
# AI stands for Artificial Intelligence. It's a broad field of computer science that deals with creating machines and systems that can perform tasks that typically require human intelligence. These tasks include:
#
# *   **Learning:** Acquiring information and rules for using the information.
# *   **Reasoning:** Using rules to reach conclusions (either definite or approximate).
# *   **Problem-solving:** Formulating a problem in a way that it can be addressed, finding a solution, and testing to see if the solution is valid.
# *   **Perception:** Acquiring information about the world through sensors (e.g., computer vision, speech recognition).
# *   **Natural Language Processing:** Understanding and generating human language.
#
# AI can be implemented in various ways, including:
#
# *   **Machine Learning:** Algorithms that allow computers to learn from data without being explicitly programmed.
# *   **Deep Learning:** A subset of machine learning that uses artificial neural networks with multiple layers to analyze data.
# *   **Rule-based Systems:** Systems that use a set of predefined rules to make decisions.
#
# AI is used in many applications today, such as:
#
# *   **Virtual assistants** (e.g., Siri, Alexa)
# *   **Recommendation systems** (e.g., Netflix, Amazon)
# *   **Self-driving cars**
# *   **Medical diagnosis**
# *   **Fraud detection**
#
# **Urdu:**
#
# AI سے مراد مصنوعی ذہانت (Artificial Intelligence) ہے۔ یہ کمپیوٹر سائنس کا ایک وسیع میدان ہے جو ایسی مشینیں اور نظام بنانے سے متعلق ہے جو ایسے کام انجام دے سکیں جن کے لیے عام طور پر انسانی ذہانت کی ضرورت ہوتی ہے۔ ان کاموں میں شامل ہیں:
#
# *   **سیکھنا (Learning):** معلومات اور معلومات کے استعمال کے قواعد حاصل کرنا۔
# *   **استدلال (Reasoning):** نتائج تک پہنچنے کے لیے قواعد کا استعمال کرنا (یا تو قطعی یا تخمینی)۔
# *   **مسئلہ حل کرنا (Problem-solving):** کسی مسئلے کو اس طرح تشکیل دینا کہ اس سے نمٹا جا سکے، حل تلاش کرنا، اور یہ جانچنا کہ آیا حل درست ہے یا نہیں۔
# *   **ادراک (Perception):** سینسرز کے ذریعے دنیا کے بارے میں معلومات حاصل کرنا (مثال کے طور پر، کمپیوٹر وژن، تقریر کی شناخت)۔
# *   **قدرتی زبان کی پروسیسنگ (Natural Language Processing):** انسانی زبان کو سمجھنا اور تیار کرنا۔
#
# AI کو مختلف طریقوں سے نافذ کیا جا سکتا ہے، بشمول:
#
# *   **مشین لرننگ (Machine Learning):** الگورتھم جو کمپیوٹروں کو واضح طور پر پروگرام کیے بغیر ڈیٹا سے سیکھنے کی اجازت دیتے ہیں۔
# *   **ڈیپ لرننگ (Deep Learning):** مشین لرننگ کا ایک ذیلی مجموعہ جو ڈیٹا کا تجزیہ کرنے کے لیے متعدد تہوں کے ساتھ مصنوعی نیورل نیٹ ورکس کا استعمال کرتا ہے۔
# *   **قاعدہ پر مبنی نظام (Rule-based Systems):** وہ نظام جو فیصلے کرنے کے لیے پہلے سے طے شدہ قواعد کا ایک مجموعہ استعمال کرتے ہیں۔
#
# AI آج بہت سی ایپلی کیشنز میں استعمال ہوتی ہے، جیسے کہ:
#
# *   **ورچوئل اسسٹنٹ (Virtual assistants)** (مثال کے طور پر، سری، الیکسا)
# *   **سفارشاتی نظام (Recommendation systems)** (مثال کے طور پر، نیٹ فلکس، ایمیزون)
# *   **خود چلنے والی کاریں (Self-driving cars)**
# *   **طبی تشخیص (Medical diagnosis)**
# *   **فراڈ کا پتہ لگانا (Fraud detection)**
