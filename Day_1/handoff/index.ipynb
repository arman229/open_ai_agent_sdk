# %%
import asyncio
import nest_asyncio
nest_asyncio.apply()

# %%
from agents import Agent,Runner,AsyncOpenAI,OpenAIChatCompletionsModel
import os  

try:
        
    GEMINI_API_KEY = os.getenv('GEMINI_API_KEY')
    if not GEMINI_API_KEY:
        raise ValueError('Gemini api key is not set in .env')
    client = AsyncOpenAI(base_url = 'https://generativelanguage.googleapis.com/v1beta/openai/',api_key=GEMINI_API_KEY)
    model = OpenAIChatCompletionsModel(model='gemini-1.5-flash',openai_client=client)
except Exception as e:
    print('Error',e)

# %%
basic_chatbot = Agent(name='basic_chatbot',instructions='You are helpful assistant ',model=model)
async def main(user_input:str):
   resp = await Runner.run(starting_agent=basic_chatbot,input=user_input)
   return resp.final_output
if __name__ == "__main__":
    final_resp = asyncio.run(main('what is AI'))
    print(final_resp)
# Out:
# AI, or Artificial Intelligence, is a broad field of computer science dedicated to creating systems capable of performing tasks that typically require human intelligence.  These tasks include things like:
#
# * **Learning:** Acquiring information and rules for using the information.
# * **Reasoning:** Using rules to reach approximate or definite conclusions.
# * **Problem-solving:** Finding solutions to complex situations.
# * **Perception:** Interpreting sensory information like images, sound, and text.
# * **Language understanding:** Processing and generating human language.
#
# There are different approaches to AI, including:
#
# * **Narrow or Weak AI:**  Designed for a specific task, like playing chess or recommending products.  This is the most common type of AI we see today.  Examples include Siri, Alexa, and spam filters.
#
# * **General or Strong AI:** Hypothetical AI with human-level intelligence and the ability to perform any intellectual task that a human being can.  This type of AI does not yet exist.
#
# * **Super AI:** Hypothetical AI that surpasses human intelligence in all aspects. This is also purely theoretical at this point.
#
# It's important to note that the term "AI" is often used loosely, and many systems labeled as AI might only employ relatively simple algorithms.  True artificial general intelligence remains a significant scientific challenge.

# %%
triage_agent = Agent(name='triage agent',instructions='You ar ',model=model)
pak_agent = Agent(name='pak agent',instructions='You have knowledge an pakistant',model=model)
india_agent = Agent(name='india agent',instructions='You have knowledge an india',model=model)
iran_agent = Agent(name='iran agent',instructions='You have knowledge an iran',model =model)

async def main(user_input:str):
   resp = await Runner.run(starting_agent=basic_chatbot,input=user_input)
   return resp.final_output
if __name__ == "__main__":
    final_resp = asyncio.run(main('what is AI'))
    print(final_resp)

# %%
from agents import Agent

history_tutor_agent = Agent(
    name="History Tutor",
    handoff_description="Specialist agent for historical questions",
    instructions="You provide assistance with historical queries. Explain important events and context clearly.",
    model=model
)

math_tutor_agent = Agent(
    name="Math Tutor",
    handoff_description="Specialist agent for math questions",
    instructions="You provide help with math problems. Explain your reasoning at each step and include examples",
    model=model
)

triage_agent = Agent(
    name="Triage Agent",
    instructions="You determine which agent to use based on the user's homework question",
    handoffs=[history_tutor_agent, math_tutor_agent],
    model=model
    
)
from agents import Runner

async def main():
    result = await Runner.run(triage_agent, "What is the capital of France?")
    print(result.final_output)
    
if __name__ == "__main__":
    final_resp = asyncio.run(main())
    print(final_resp)
# Out:
# The capital of France is Paris.  This has been the case for centuries, although the precise definition of "capital" and the location of governmental functions have shifted slightly throughout French history.  Paris's status as the capital solidified over a long period, beginning with its prominence during the reign of King Philip II Augustus in the late 12th and early 13th centuries.  Its central location, navigable river (the Seine), and strategic importance made it a natural choice for the seat of power.
#
# None
