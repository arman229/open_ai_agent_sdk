# %%
import nest_asyncio

nest_asyncio.apply()
# 1. AGENT LEVEL
import os
from agents import Agent, OpenAIChatCompletionsModel, AsyncOpenAI, Runner
import asyncio
try:

    GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")
    if not GEMINI_API_KEY:
        raise ValueError("GEMINI ApI key not found")
  
    external_client = AsyncOpenAI(
        base_url="https://generativelanguage.googleapis.com/v1beta/openai/",
        api_key=GEMINI_API_KEY,
    )
    model = OpenAIChatCompletionsModel(
        model="gemini-2.0-flash", openai_client=external_client
    )
except Exception as e:
    print("Error", e)

# %%
import asyncio
from openai.types.responses import ResponseTextDeltaEvent
from agents import Agent, Runner

async def main():
    agent = Agent(
        name="Joker",
        instructions="You are a helpful assistant.",
        model=model
    )

    result = Runner.run_streamed(agent, input="Please tell me 5 jokes.")
    # print(result)
    # print(result.current_agent)
    # print(result.current_turn)
    async for event in result.stream_events():
        # print(event)
        if event.type == "raw_response_event" and isinstance(event.data, ResponseTextDeltaEvent):
            return event.data.delta


if __name__ == "__main__":
    resp=asyncio.run(main())
    print(resp)
# Out:
# Okay

# %%
import asyncio
import random
from agents import Agent, ItemHelpers, Runner, function_tool

@function_tool
def how_many_jokes() -> int:
    return random.randint(1, 10)


async def main():
    agent = Agent(
        name="Joker",
        instructions="First call the `how_many_jokes` tool, then tell that many jokes.",
        tools=[how_many_jokes],
        model=model
    )

    result = Runner.run_streamed(
        agent,
        input="Hello",
    )
    print("=== Run starting ===")

    async for event in result.stream_events():
        # We'll ignore the raw responses event deltas
        if event.type == "raw_response_event":
            continue
        # When the agent updates, print that
        elif event.type == "agent_updated_stream_event":
            print(f"Agent updated: {event.new_agent.name}")
            continue
        # When items are generated, print them
        elif event.type == "run_item_stream_event":
            if event.item.type == "tool_call_item":
                print("-- Tool was called")
            elif event.item.type == "tool_call_output_item":
                print(f"-- Tool output: {event.item.output}")
            elif event.item.type == "message_output_item":
                print(f"-- Message output:\n {ItemHelpers.text_message_output(event.item)}")
            else:
                pass  # Ignore other event types

    print("=== Run complete ===")


if __name__ == "__main__":
    asyncio.run(main())
# Out:
# === Run starting ===
# Agent updated: Joker
# -- Tool was called
# -- Tool output: 5
# -- Message output:
#  I will tell you 5 jokes.
#
# Why don't scientists trust atoms?
# Because they make up everything!
#
# Parallel lines have so much in common.
# It’s a shame they’ll never meet.
#
# Why did the scarecrow win an award?
# Because he was outstanding in his field!
#
# Why did the bicycle fall over?
# Because it was two tired!
#
# What do you call a fish with no eyes?
# Fsh!
#
# === Run complete ===
# OPENAI_API_KEY is not set, skipping trace export
# OPENAI_API_KEY is not set, skipping trace export
# OPENAI_API_KEY is not set, skipping trace export
# OPENAI_API_KEY is not set, skipping trace export
# OPENAI_API_KEY is not set, skipping trace export
# OPENAI_API_KEY is not set, skipping trace export
# OPENAI_API_KEY is not set, skipping trace export
# OPENAI_API_KEY is not set, skipping trace export
# OPENAI_API_KEY is not set, skipping trace export
# OPENAI_API_KEY is not set, skipping trace export

# %%
import asyncio
import random
from agents import Agent, ItemHelpers, Runner, function_tool

@function_tool
def how_many_jokes() -> int:
    return random.randint(1, 10)


async def main():
    agent = Agent(
        name="Joker",
        instructions="you are helpful assiatant",
        # tools=[how_many_jokes],
        model=model
    )

    result = Runner.run_streamed(
        agent,
        input="what is ai in 500 words",
    )
    print("=== Run starting ===")

    async for event in result.stream_events():
        # We'll ignore the raw responses event deltas
        if event.type == "raw_response_event":
            continue
        # When the agent updates, print that
        elif event.type == "agent_updated_stream_event":
            print(f"Agent updated: {event.new_agent.name}")
            continue
        # When items are generated, print them
        elif event.type == "run_item_stream_event":
            if event.item.type == "tool_call_item":
                print("-- Tool was called")
            elif event.item.type == "tool_call_output_item":
                print(f"-- Tool output: {event.item.output}")
            elif event.item.type == "message_output_item":
                print(f"-- Message output:\n {ItemHelpers.text_message_output(event.item)}")
            else:
                pass  # Ignore other event types

    print("=== Run complete ===")


if __name__ == "__main__":
    asyncio.run(main())
# Out:
# === Run starting ===
# Agent updated: Joker
# -- Message output:
#  Artificial intelligence (AI) is a broad field of computer science dedicated to creating machines that can perform tasks that typically require human intelligence. Instead of just following pre-programmed instructions, AI aims to enable computers to learn, reason, problem-solve, perceive, and understand natural language. It’s about making machines "smart" enough to mimic human cognitive abilities.
#
# The core idea behind AI is to develop algorithms and computational models that allow machines to:
#
# *   **Learn from data:** This is often achieved through machine learning, where algorithms are trained on large datasets to identify patterns and make predictions.
# *   **Reason and solve problems:** AI systems can use logic, deduction, and inference to draw conclusions and find solutions to complex problems.
# *   **Perceive the world:** Computer vision, natural language processing, and speech recognition enable AI systems to "see," "hear," and "understand" the world around them.
# *   **Understand natural language:** NLP allows AI to process and interpret human language, enabling tasks like translation, chatbot interactions, and text summarization.
#
# AI is not a single technology but rather an umbrella term encompassing various subfields and techniques. Some key areas within AI include:
#
# *   **Machine Learning (ML):** Focuses on algorithms that learn from data without explicit programming.  Subsets of ML include:
#     *   **Supervised learning:** Training algorithms on labeled data.
#     *   **Unsupervised learning:** Discovering patterns in unlabeled data.
#     *   **Reinforcement learning:** Training agents to make decisions through trial and error, based on rewards.
# *   **Deep Learning:** A subset of machine learning that uses artificial neural networks with multiple layers (deep neural networks) to analyze data and extract complex features. This is particularly effective in image recognition, speech recognition, and natural language processing.
# *   **Natural Language Processing (NLP):** Enables computers to understand, interpret, and generate human language.
# *   **Computer Vision:** Enables computers to "see" and interpret images, videos, and other visual data.
# *   **Robotics:** Integrates AI with physical robots to perform tasks in the real world.
#
# AI is already transforming numerous industries. In healthcare, AI assists with diagnosis, drug discovery, and personalized treatment. In finance, it's used for fraud detection, algorithmic trading, and risk assessment.  In manufacturing, AI powers automation, quality control, and predictive maintenance.  Self-driving cars, virtual assistants like Siri and Alexa, and personalized recommendation systems are all examples of AI in action.
#
# The potential of AI is vast, but it also raises ethical concerns.  Bias in algorithms, job displacement, and the potential misuse of AI for malicious purposes are all important issues that need to be addressed.  Responsible development and deployment of AI are crucial to ensuring that it benefits humanity as a whole. The future of AI promises further advancements, leading to even more intelligent and capable machines that will continue to reshape our world.
#
# === Run complete ===

# %%
import asyncio
from openai.types.responses import ResponseTextDeltaEvent
from agents import Agent, Runner

async def main():
    agent = Agent(
        name="Joker",
        instructions="You are a helpful assistant.",
        model=model
    )

    result = Runner.run_streamed(agent, input="Please tell me allama iqbal in 500 words.")
    async for event in result.stream_events():
        if event.type == "raw_response_event" and isinstance(event.data, ResponseTextDeltaEvent):
            print(event.data.delta, end="", flush=True)


if __name__ == "__main__":
    asyncio.run(main())
# Out:
# Allama Muhammad Iqbal, widely regarded as the "Poet of the East," was a philosopher, poet, and politician whose work profoundly influenced the Pakistan Movement and shaped the intellectual landscape of the 20th century. Born in Sialkot, British India (now Pakistan), on November 9, 1877, Iqbal's life was a quest for spiritual and intellectual enlightenment, which he poured into his Persian and Urdu poetry and philosophical writings.
#
# Iqbal received his early education in Sialkot, memorizing the Quran and studying Arabic and Persian. He then attended Government College Lahore, where he studied philosophy and literature. His brilliance led him to further studies in Europe, first at Cambridge University and then at the University of Munich, where he earned a doctorate in philosophy. These experiences broadened his intellectual horizons, exposing him to Western philosophical thought while simultaneously reinforcing his commitment to Islamic principles.
#
# Initially, Iqbal’s poetry reflected themes of patriotism and unity, evident in his famous poem "Tarana-e-Hindi" (Song of India). However, his European experience led him to critique Western materialism and the decline of spirituality. He began to advocate for the revival of Islamic values and a reinterpretation of Islamic philosophy to address the challenges of the modern world. This shift is evident in his later works, which emphasize self-reliance (Khudi), the importance of action (Amal), and the creation of a dynamic and progressive Muslim society.
#
# His magnum opus, "Asrar-i-Khudi" (The Secrets of the Self), published in Persian, became a cornerstone of his philosophical system. It emphasizes the importance of self-affirmation and the development of the individual's potential, drawing inspiration from Islamic mysticism and emphasizing the need for active participation in shaping one's destiny. He argued that the realization of the "self" through love, knowledge, and willpower could lead to a more fulfilling and meaningful life.
#
# Iqbal's other notable works include "Rumuz-i-Bekhudi" (The Mysteries of Selflessness), which complements "Asrar-i-Khudi" by focusing on the importance of community and social responsibility. He believed that individual development should ultimately contribute to the betterment of society as a whole. "Bang-i-Dara" (The
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 19
#      15             print(event.data.delta, end="", flush=True)
#      18 if __name__ == "__main__":
# ---> 19     asyncio.run(main())
#
# File e:\code\open_ai_agent_sdk\.venv\Lib\site-packages\nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File e:\code\open_ai_agent_sdk\.venv\Lib\site-packages\nest_asyncio.py:92, in _patch_loop.<locals>.run_until_complete(self, future)
#      90     f._log_destroy_pending = False
#      91 while not f.done():
# ---> 92     self._run_once()
#      93     if self._stopping:
#      94         break
#
# File e:\code\open_ai_agent_sdk\.venv\Lib\site-packages\nest_asyncio.py:115, in _patch_loop.<locals>._run_once(self)
#     108     heappop(scheduled)
#     110 timeout = (
#     111     0 if ready or self._stopping
#     112     else min(max(
#     113         scheduled[0]._when - self.time(), 0), 86400) if scheduled
#     114     else None)
# --> 115 event_list = self._selector.select(timeout)
#     116 self._process_events(event_list)
#     118 end_time = self.time() + self._clock_resolution
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\selectors.py:314, in SelectSelector.select(self, timeout)
#     312 ready = []
#     313 try:
# --> 314     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     315 except InterruptedError:
#     316     return ready
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\selectors.py:305, in SelectSelector._select(self, r, w, _, timeout)
#     304 def _select(self, r, w, _, timeout=None):
# --> 305     r, w, x = select.select(r, w, w, timeout)
#     306     return r, w + x, []
#
# KeyboardInterrupt:
