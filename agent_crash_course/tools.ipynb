# %%
import nest_asyncio

nest_asyncio.apply()
# 1. AGENT LEVEL
import os
from agents import Agent, OpenAIChatCompletionsModel, AsyncOpenAI, Runner
import asyncio
try:

    GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")
    if not GEMINI_API_KEY:
        raise ValueError("GEMINI ApI key not found")
  
    external_client = AsyncOpenAI(
        base_url="https://generativelanguage.googleapis.com/v1beta/openai/",
        api_key=GEMINI_API_KEY,
    )
    model = OpenAIChatCompletionsModel(
        model="gemini-2.0-flash", openai_client=external_client
    )
except Exception as e:
    print("Error", e)

# %%
import asyncio
from typing import Any

from pydantic import BaseModel
from agents import Agent, Runner, RunContextWrapper, FunctionTool

 
def do_some_work(data: str) -> str:
    return f"✅ Processed: {data}"

 
class FunctionArgs(BaseModel):
    username: str
    age: int

 
async def run_function(ctx: RunContextWrapper[Any], args: str) -> str:
    parsed = FunctionArgs.model_validate_json(args)
    return do_some_work(data=f"{parsed.username} is {parsed.age} years old")

 
tool = FunctionTool(
    name="process_user",
    description="Processes extracted user data like name and age",
    params_json_schema=FunctionArgs.model_json_schema(),
    on_invoke_tool=run_function,
)

 
agent = Agent(
    name="InfoAgent",
    instructions="You must always use the 'process_user' tool to summarize the user's info.",
    tools=[tool],
    model = model
)

 
async def main():
    result = Runner.run_sync(agent, input="My name is Arman and I am from pakistan")
    print("🎯 Final Output:", result.final_output)


if __name__ == "__main__":
    asyncio.run(main())
# Out:
# 🎯 Final Output: Could you please provide me with your age?

# %%
import asyncio
from typing import Any

from pydantic import BaseModel
from agents import Agent, Runner, RunContextWrapper, FunctionTool

 
def do_some_work(data: str) -> str:
    return f"✅ Processed: {data}"

 
class FunctionArgs(BaseModel):
    username: str
    age: int

 
async def run_function(ctx: RunContextWrapper[Any], args: str) -> str:
    parsed = FunctionArgs.model_validate_json(args)
    return do_some_work(data=f"{parsed.username} is {parsed.age} years old")

 
tool = FunctionTool(
    name="process_user",
    description="Processes extracted user data like name and age",
    params_json_schema=FunctionArgs,
    on_invoke_tool=run_function,
)

 
agent = Agent(
    name="InfoAgent",
    instructions="You must always use the 'process_user' tool to summarize the user's info.",
    tools=[tool],
    model = model
)

 
async def main():
    result = Runner.run_sync(agent, input="My name is Arman and I am from pakistan")
    print("🎯 Final Output:", result.final_output)


if __name__ == "__main__":
    asyncio.run(main())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 44
#      40     print("🎯 Final Output:", result.final_output)
#      43 if __name__ == "__main__":
# ---> 44     asyncio.run(main())
#
# File e:\code\open_ai_agent_sdk\.venv\lib\site-packages\nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File e:\code\open_ai_agent_sdk\.venv\lib\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File C:\Program Files\Python39\lib\asyncio\futures.py:201, in Future.result(self)
# ...

# %%
import asyncio
from typing import Any

from pydantic import BaseModel
from agents import Agent, Runner, RunContextWrapper, FunctionTool

 
def do_some_work(data: str) -> str:
    return f"✅ Processed: {data}"

 
class FunctionArgs(BaseModel):
    username: str
    age: int

 
async def run_function(ctx: RunContextWrapper[Any], args: str) -> str:
    parsed = FunctionArgs.model_validate_json(args)
    # return do_some_work(data=f"{parsed.username} is {parsed.age} years old")
    return RuntimeError('error')
 
tool = FunctionTool(
    name="process_user",
    description="Processes extracted user data like name and age",
    params_json_schema=FunctionArgs,
    on_invoke_tool=run_function,
)

 
agent = Agent(
    name="InfoAgent",
    instructions="You must always use the 'process_user' tool to summarize the user's info.",
    tools=[tool],
    model = model
)

 
async def main():
    result = Runner.run_sync(agent, input="My name is Arman and I am from pakistan")
    print("🎯 Final Output:", result.final_output)


if __name__ == "__main__":
    asyncio.run(main())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 44
#      40     print("🎯 Final Output:", result.final_output)
#      43 if __name__ == "__main__":
# ---> 44     asyncio.run(main())
#
# File e:\code\open_ai_agent_sdk\.venv\lib\site-packages\nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File e:\code\open_ai_agent_sdk\.venv\lib\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File C:\Program Files\Python39\lib\asyncio\futures.py:201, in Future.result(self)
# ...

# %%
import asyncio
from typing import Any

from pydantic import BaseModel
from agents import Agent, Runner, RunContextWrapper, FunctionTool

 
def do_some_work(data: str) -> str:
    return f"✅ Processed: {data}"

 
class FunctionArgs(BaseModel):
    username: str
    age: int

 
async def run_function(ctx: RunContextWrapper[Any], args: str) -> str:
    parsed = FunctionArgs.model_validate_json(args)
    # return do_some_work(data=f"{parsed.username} is {parsed.age} years old")
    return RuntimeError('error')
 
tool = FunctionTool(
    name="process_user",
    description="Processes extracted user data like name and age",
    params_json_schema=FunctionArgs,
    on_invoke_tool=run_function,
    is_enabled=False
)

 
agent = Agent(
    name="InfoAgent",
    instructions="You must always use the 'process_user' tool to summarize the user's info.",
    tools=[tool],
    model = model
)

 
async def main():
    result = Runner.run_sync(agent, input="My name is Arman and I am from pakistan")
    print("🎯 Final Output:", result.final_output)


if __name__ == "__main__":
    asyncio.run(main())
# Out:
# 🎯 Final Output: ```tool_code
# process_user(name="Arman", country="Pakistan")
# ```

# %%
import asyncio
from typing import Any

from pydantic import BaseModel
from agents import Agent, Runner, RunContextWrapper, FunctionTool

 
def do_some_work(data: str) -> str:
    return f"✅ Processed: {data}"

 
class FunctionArgs(BaseModel):
    username: str
    age: int

 
async def run_function(ctx: RunContextWrapper[Any], args: str) -> str:
    parsed = FunctionArgs.model_validate_json(args)
    # return do_some_work(data=f"{parsed.username} is {parsed.age} years old")
    return RuntimeError('error')
 
tool = FunctionTool(
    name="process_user",
    description="Processes extracted user data like name and age",
    params_json_schema=FunctionArgs,
    on_invoke_tool=run_function,
    is_enabled=False
)

 
agent = Agent(
    name="InfoAgent",
    instructions="You must always use the 'process_user' tool to summarize the user's info.",
    # tools=[tool],
    model = model
)

 
async def main():
    result = Runner.run_sync(agent, input="My name is Arman and I am from pakistan")
    print("🎯 Final Output:", result.final_output)


if __name__ == "__main__":
    asyncio.run(main())
# Out:
# 🎯 Final Output: ```tool_code
# process_user(name="Arman", country="pakistan")
# ```

# %%
import asyncio
from typing import Any
from pydantic import BaseModel
from agents import Agent, FunctionTool, Runner, RunContextWrapper

# Pydantic model for expected arguments
class UserInfo(BaseModel):
    name: str
    age: int

# Function logic
async def run_tool(ctx: RunContextWrapper[Any], args: str) -> str:
    print(f'args:{args}')
    parsed = UserInfo.model_validate_json(args)
    print(f"parsed:",parsed)
    return f"{parsed.name} is {parsed.age} years old."
tool = FunctionTool(
    name="process_user_info",
    description="Process user's name and age",
    params_json_schema=UserInfo.model_json_schema(),
    on_invoke_tool=run_tool,
    strict_json_schema=False,  # ⚠️ Loose validation
    is_enabled=''
)
async def main():
    agent = Agent(
        name="FlexibleAgent",
        instructions="Call the process_user_info tool with name and age. You can pass extra fields.",
        tools=[tool],
        model=model
    )

    result = await Runner.run(agent, input="My name is Arman, I'm   Python.")
    print(result.final_output)

if __name__ == "__main__":
    asyncio.run(main())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 37
#      34     print(result.final_output)
#      36 if __name__ == "__main__":
# ---> 37     asyncio.run(main())
#
# File e:\code\open_ai_agent_sdk\.venv\lib\site-packages\nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File e:\code\open_ai_agent_sdk\.venv\lib\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File C:\Program Files\Python39\lib\asyncio\futures.py:201, in Future.result(self)
#     199 self.__log_traceback = False
# ...

# %%
import asyncio
from typing import Any
from pydantic import BaseModel
from agents import Agent, FunctionTool, Runner, RunContextWrapper

# Pydantic model for expected arguments
class UserInfo(BaseModel):
    name: str
    age: int

# Function logic
async def run_tool(ctx: RunContextWrapper[Any], args: str) -> str:
    print(f'args:{args}')
    parsed = UserInfo.model_validate_json(args)
    print(f"parsed:",parsed)
    return f"{parsed.name} is {parsed.age} years old."
tool = FunctionTool(
    name="process_user_info",
    description=" ",
    params_json_schema=UserInfo.model_json_schema(),
    on_invoke_tool=run_tool,
    
    
)
async def main():
    agent = Agent(
        name="FlexibleAgent",
        instructions="Call the process_user_info tool with name and age. You can pass extra fields.",
        tools=[tool],
        model=model
    )

    result = await Runner.run(agent, input="My name is Arman, I'm 22 year Python.")
    print(result.final_output)

if __name__ == "__main__":
    asyncio.run(main())
# Out:
# args:{"name":"Arman","age":22}
# parsed: name='Arman' age=22
# OK. I've processed your information. Arman is 22 years old.
