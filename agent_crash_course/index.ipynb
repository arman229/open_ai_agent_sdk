# %%
import nest_asyncio

nest_asyncio.apply() 
import os
from agents import Agent, OpenAIChatCompletionsModel, AsyncOpenAI, Runner
import asyncio
try:

    GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")
    if not GEMINI_API_KEY:
        raise ValueError("GEMINI ApI key not found")
  
    external_client = AsyncOpenAI(
        base_url="https://generativelanguage.googleapis.com/v1beta/openai/",
        api_key=GEMINI_API_KEY,
    )
    model = OpenAIChatCompletionsModel(
        model="gemini-2.0-flash", openai_client=external_client
    )
except Exception as e:
    print("Error", e)

# %%
# Example: Stack overflow
def call_fun(n):
    if n <= 1:
        return n
    return call_fun(n-1) + call_fun(n-2)

print("Main thread starts")
call_fun(10000)  # Likely causes RecursionError, stopping the main thread

# %%
 
def call_fun(n):
    if n <= 1:
        return n
    return call_fun(n-1) + call_fun(n-2)

print("Main thread starts")
call_fun(35)
# Out:
# Main thread starts
# 9227465

# %%
from functools import total_ordering
import time
from agents import Agent, ModelSettings,function_tool
def call_fun(n):
    if n<=1:
        return n
    return call_fun(n-1)+call_fun(n-2)

@function_tool
def find_fabonci_no(no:int):
    print('fabonci no')    
    start_time = time.time()
    print(f'start time: {start_time}')
    resp = str(call_fun(no))
    end_time = time.time()
    print(f' find_fabonci_no total time takes: {end_time-start_time:.3f}')
    return resp


@function_tool
def find_priminister(country:str):
    start_time = time.time()
    print(f'start time: {start_time}')
    print('Country priminister')    
    resp = f'Imran khan is the priminister of {country}'
    print(resp)
    end_time = time.time()
    print(f'find_priminister total time takes: {end_time-start_time:.3f}')
    return resp


 

basic_agent = Agent(name='basic_agent',tools=[find_fabonci_no,find_priminister], instructions='you are helpful assistant ',model=model ,tool_use_behavior='stop_on_first_tool'                   )

resp = Runner.run_sync(basic_agent,input='we want to calculate fabonichi no of 10 and who is the priminster of pakistan ')
print(resp.final_output)
# Out:
# fabonci no
# start time: 1752839898.5595777
#  find_fabonci_no total time takes: 2.434
# start time: 1752839900.9937975
# Country priminister
# Imran khan is the priminister of pakistan
# find_priminister total time takes: 0.000
# 9227465

# %%
from functools import total_ordering
import time
from agents import Agent, ModelSettings,function_tool
async def call_fun(n):
    if n<=1:
        return n
    return await call_fun(n-1)+await call_fun(n-2)

@function_tool
async def find_fabonci_no(no:int):
    print('fabonci no')    
    start_time = time.time()
    print(f'start time: {start_time}')
    resp = str(await call_fun(no))
    end_time = time.time()
    print(f' find_fabonci_no total time takes: {end_time-start_time:.3f}')
    return resp


@function_tool
def find_priminister(country:str):
    start_time = time.time()
    print(f'start time: {start_time}')
    print('Country priminister')    
    resp = f'Imran khan is the priminister of {country}'
    print(resp)
    end_time = time.time()
    print(f'find_priminister total time takes: {end_time-start_time:.3f}')
    return resp


 

basic_agent = Agent(name='basic_agent',tools=[find_fabonci_no,find_priminister], instructions='you are helpful assistant ',model=model ,tool_use_behavior='stop_on_first_tool'                   )

resp = Runner.run_sync(basic_agent,input='we want to calculate fabonichi no of 35 and who is the priminster of pakistan ')
print(resp.final_output)
# Out:
# fabonci no
# start time: 1752665697.2078161
#  find_fabonci_no total time takes: 5.835
# start time: 1752665703.0433657
# Country priminister
# Imran khan is the priminister of pakistan
# find_priminister total time takes: 0.000
# 9227465

# %%
from functools import total_ordering
import time
from agents import Agent, ModelSettings,function_tool
async def call_fun(n):
    if n<=1:
        return n
    return await call_fun(n-1)+await call_fun(n-2)

@function_tool
async def find_fabonci_no(no:int):
    print('fabonci no')    
    start_time = time.time()
    print(f'start time: {start_time}')
    resp = str(await call_fun(no))
    end_time = time.time()
    print(f' find_fabonci_no total time takes: {end_time-start_time:.3f}')
    return resp


@function_tool
def find_priminister(country:str):
    start_time = time.time()
    print(f'start time: {start_time}')
    print('Country priminister')    
    resp = f'Imran khan is the priminister of {country}'
    print(resp)
    end_time = time.time()
    print(f'find_priminister total time takes: {end_time-start_time:.3f}')
    return resp


 

basic_agent = Agent(name='basic_agent',tools=[find_fabonci_no,find_priminister], instructions='you are helpful assistant ',model=model ,tool_use_behavior='stop_on_first_tool'                   )

resp = await Runner.run(basic_agent,input='we want to calculate fabonichi no of 35 and who is the priminster of pakistan ')
print(resp.final_output)
# Out:
# fabonci no
# start time: 1752665860.8950489
#  find_fabonci_no total time takes: 6.117
# start time: 1752665867.0125701
# Country priminister
# Imran khan is the priminister of pakistan
# find_priminister total time takes: 0.000
# 9227465

# %%
from functools import total_ordering
import time
from agents import Agent, ModelSettings,function_tool
def call_fun(n):
    if n<=1:
        return n
    return call_fun(n-1)+call_fun(n-2)

@function_tool
def find_fabonci_no(no:int):
    print('fabonci no')    
    start_time = time.time()
    print(f'start time: {start_time}')
    # resp = str(call_fun(no))
    time.sleep(4)
    resp = '49'
    end_time = time.time()
    print(f' find_fabonci_no total time takes: {end_time-start_time:.3f}')
    return resp


@function_tool
def find_priminister(country:str):
    start_time = time.time()
    print(f'start time: {start_time}')
    print('Country priminister')    
    resp = f'Imran khan is the priminister of {country}'
    print(resp)
    end_time = time.time()
    print(f'find_priminister total time takes: {end_time-start_time:.3f}')
    return resp


 

basic_agent = Agent(name='basic_agent',tools=[find_fabonci_no,find_priminister], instructions='you are helpful assistant ',model=model ,tool_use_behavior='stop_on_first_tool'                   )

resp = Runner.run_sync(basic_agent,input='we want to calculate fabonichi no of 35 and who is the priminster of pakistan ')
print(resp.final_output)
# Out:
# fabonci no
# start time: 1752666820.713716
#  find_fabonci_no total time takes: 4.000
# start time: 1752666824.7146406
# Country priminister
# Imran khan is the priminister of pakistan
# find_priminister total time takes: 0.000
# 49

# %%
from functools import total_ordering
import time
from agents import Agent, ModelSettings,function_tool
def call_fun(n):
    if n<=1:
        return n
    return call_fun(n-1)+call_fun(n-2)

@function_tool
async def find_fabonci_no(no:int):
    print('fabonci no')    
    start_time = time.time()
    print(f'start time: {start_time}')
    # resp = str(call_fun(no))
    await asyncio.sleep(4)
    resp = '49'
    end_time = time.time()
    print(f' find_fabonci_no total time takes: {end_time-start_time:.3f}')
    return resp


@function_tool
def find_priminister(country:str):
    start_time = time.time()
    print(f'start time: {start_time}')
    print('Country priminister')    
    resp = f'Imran khan is the priminister of {country}'
    print(resp)
    end_time = time.time()
    print(f'find_priminister total time takes: {end_time-start_time:.3f}')
    return resp


 

basic_agent = Agent(name='basic_agent',tools=[find_fabonci_no,find_priminister], instructions='you are helpful assistant ',model=model ,tool_use_behavior='stop_on_first_tool'                   )

resp = Runner.run_sync(basic_agent,input='we want to calculate fabonichi no of 35 and who is the priminster of pakistan ')
print(resp.final_output)
# Out:
# fabonci no
# start time: 1752666897.0271802
# start time: 1752666897.0273013
# Country priminister
# Imran khan is the priminister of pakistan
# find_priminister total time takes: 0.000
#  find_fabonci_no total time takes: 4.003
# 49

# %%
from functools import total_ordering
import time
from agents import Agent, ModelSettings,function_tool
def call_fun(n):
    if n<=1:
        return n
    return call_fun(n-1)+call_fun(n-2)

@function_tool
async def find_fabonci_no(no:int):
    print('fabonci no')    
    start_time = time.time()
    print(f'start time: {start_time}')
    # resp = str(call_fun(no))
    await asyncio.sleep(4)
    raise ValueError('Some error ')
    end_time = time.time()
    print(f' find_fabonci_no total time takes: {end_time-start_time:.3f}')
    return resp


@function_tool
def find_priminister(country:str):
    start_time = time.time()
    print(f'start time: {start_time}')
    print('Country priminister')    
    resp = f'Imran khan is the priminister of {country}'
    print(resp)
    end_time = time.time()
    print(f'find_priminister total time takes: {end_time-start_time:.3f}')
    return resp


 

basic_agent = Agent(name='basic_agent',tools=[find_fabonci_no,find_priminister], instructions='you are helpful assistant ',model=model ,tool_use_behavior='stop_on_first_tool'                   )

resp = Runner.run_sync(basic_agent,input='we want to calculate fabonichi no of 35 and who is the priminster of pakistan ')
print(resp.final_output)
# Out:
# fabonci no
# start time: 1752666981.9516814
# start time: 1752666981.9518685
# Country priminister
# Imran khan is the priminister of pakistan
# find_priminister total time takes: 0.000
# An error occurred while running the tool. Please try again. Error: Some error

# %%
from functools import total_ordering
import time
from agents import Agent, ModelSettings,function_tool
def call_fun(n):
    if n<=1:
        return n
    return call_fun(n-1)+call_fun(n-2)

@function_tool
async def find_fabonci_no(no:int):
    print('fabonci no')    
    start_time = time.time()
    print(f'start time: {start_time}')
    # resp = str(call_fun(no))
    await asyncio.sleep(4)
    raise ValueError('Some error in find fabonchi fun ')
    end_time = time.time()
    print(f' find_fabonci_no total time takes: {end_time-start_time:.3f}')
    return resp


@function_tool
def find_priminister(country:str):
    start_time = time.time()
    print(f'start time: {start_time}')
    print('Country priminister')    
    resp = f'Imran khan is the priminister of {country}'
    print(resp)
    end_time = time.time()
    print(f'find_priminister total time takes: {end_time-start_time:.3f}')
    raise ValueError('Some error in priminster func ')
    return resp


 

basic_agent = Agent(name='basic_agent',tools=[find_fabonci_no,find_priminister], instructions='you are helpful assistant ',model=model ,tool_use_behavior='stop_on_first_tool'                   )

resp = Runner.run_sync(basic_agent,input='we want to calculate fabonichi no of 35 and who is the priminster of pakistan ')
print(resp.final_output)
# Out:
# fabonci no
# start time: 1752667177.741331
# start time: 1752667177.7414525
# Country priminister
# Imran khan is the priminister of pakistan
# find_priminister total time takes: 0.000
# An error occurred while running the tool. Please try again. Error: Some error in find fabonchi fun

# %%
from functools import total_ordering
import time
from agents import Agent, ModelSettings,function_tool
def call_fun(n):
    if n<=1:
        return n
    return call_fun(n-1)+call_fun(n-2)

@function_tool
async def find_fabonci_no(no:int):
    print('fabonci no')    
    start_time = time.time()
    print(f'start time: {start_time}')
    # resp = str(call_fun(no))
    time.sleep(4)
    raise ValueError('Some error in find fabonchi fun ')
    end_time = time.time()
    print(f' find_fabonci_no total time takes: {end_time-start_time:.3f}')
    return resp


@function_tool
def find_priminister(country:str):
    start_time = time.time()
    print(f'start time: {start_time}')
    print('Country priminister')    
    resp = f'Imran khan is the priminister of {country}'
    print(resp)
    end_time = time.time()
    print(f'find_priminister total time takes: {end_time-start_time:.3f}')
    
    raise ValueError('Some error in priminster func ')
    return resp


 

basic_agent = Agent(name='basic_agent',tools=[find_fabonci_no,find_priminister], instructions='you are helpful assistant ',model=model ,tool_use_behavior='stop_on_first_tool'                   )

resp = Runner.run_sync(basic_agent,input='we want to calculate fabonichi no of 35 and who is the priminster of pakistan ')
print(resp.final_output)
# Out:
# fabonci no
# start time: 1752667423.8589666
# start time: 1752667427.860114
# Country priminister
# Imran khan is the priminister of pakistan
# find_priminister total time takes: 0.000
# An error occurred while running the tool. Please try again. Error: Some error in find fabonchi fun

# %%
from functools import total_ordering
import time
from agents import Agent, ModelSettings,function_tool
def call_fun(n):
    if n<=1:
        return n
    return call_fun(n-1)+call_fun(n-2)

@function_tool
async def find_fabonci_no(no:int):
    print('fabonci no')    
    start_time = time.time()
    print(f'start time: {start_time}')
    # resp = str(call_fun(no))
    time.sleep(4)
    
    end_time = time.time()
    print(f' find_fabonci_no total time takes: {end_time-start_time:.3f}')
    return 2 +'2'


@function_tool
def find_priminister(country:str):
    start_time = time.time()
    print(f'start time: {start_time}')
    print('Country priminister')    
    resp = f'Imran khan is the priminister of {country}'
    print(resp)
    end_time = time.time()
    print(f'find_priminister total time takes: {end_time-start_time:.3f}')
    
    raise ValueError('Some error in priminster func ')
    return resp


 

basic_agent = Agent(name='basic_agent',tools=[find_fabonci_no,find_priminister], instructions='you are helpful assistant ',model=model ,tool_use_behavior='stop_on_first_tool'                   )

resp = Runner.run_sync(basic_agent,input='we want to calculate fabonichi no of 35 and who is the priminster of pakistan ')
print(resp.final_output)
# Out:
# fabonci no
# start time: 1752667519.433135
#  find_fabonci_no total time takes: 4.000
# start time: 1752667523.434069
# Country priminister
# Imran khan is the priminister of pakistan
# find_priminister total time takes: 0.000
# An error occurred while running the tool. Please try again. Error: unsupported operand type(s) for +: 'int' and 'str'

# %%
from functools import total_ordering
from agents import Agent, ModelSettings,function_tool
async def call_fun(n):
    if n<=1:
        return n
    return await call_fun(n-1)+await call_fun(n-2)

@function_tool
async def find_fabonci_no(no:int):
    print('findfabonci_no')
    return str(await call_fun(no))

basic_agent = Agent(name='basic_agent',tools=[find_fabonci_no], instructions='you are helpful assistant always call find_fabonci_no function ',model=model ,tool_use_behavior='stop_on_first_tool'                   )

resp = Runner.run_sync(basic_agent,input='we want to calculate fabonichi no of 10')
print(resp.final_output)
# Out:
# findfabonci_no
# 55

# %%
from functools import total_ordering
from agents import Agent, ModelSettings,function_tool
async def call_fun(n):
    if n<=1:
        return n
    return await call_fun(n-1)+await call_fun(n-2)

@function_tool
async def find_fabonci_no(no:int):
    print('findfabonci_no')
    return str(await call_fun(no))

basic_agent = Agent(name='basic_agent',tools=[find_fabonci_no], instructions='you are helpful assistant always call find_fabonci_no function ',model=model ,tool_use_behavior='stop_on_first_tool'                   )

resp = Runner.run_sync(basic_agent,input='we want to calculate fabonichi no of 10')
print(resp.final_output)
# Out:
# findfabonci_no
# 55

# %%
  
from agents import Agent, ModelSettings,function_tool
async def call_fun(n):
    if n<=1:
        return n
    return await call_fun(n-1)+await call_fun(n-2)

@function_tool
async def find_fabonci_no(no:int):
    print('findfabonci_no')
    return str(await call_fun(no))

basic_agent = Agent(name='basic_agent',tools=[find_fabonci_no], instructions='you are helpful assistant always call find_fabonci_no function ',model=model ,tool_use_behavior='stop_on_first_tool'                   )

resp =await Runner.run(basic_agent,input='we want to calculate fabonichi no of 10')
print(resp.final_output)
# Out:
# findfabonci_no
# 55

# %%
from functools import total_ordering
from agents import Agent, ModelSettings,function_tool
def call_fun(n):
    if n<=1:
        return n
    return call_fun(n-1)+call_fun(n-2)

@function_tool
async def find_fabonci_no(no:int):
    print('findfabonci_no')
    return str(call_fun(no))

basic_agent = Agent(name='basic_agent',tools=[find_fabonci_no], instructions='you are helpful assistant always call find_fabonci_no function ',model=model ,tool_use_behavior='stop_on_first_tool'                   )

resp =await Runner.run(basic_agent,input='we want to calculate fabonichi no of 10')
print(resp.final_output)
# Out:
# findfabonci_no
# 55

# %%
from functools import total_ordering
from agents import Agent, ModelSettings,function_tool
def call_fun(n):
    if n<=1:
        return n
    return call_fun(n-1)+call_fun(n-2)

@function_tool
async def find_fabonci_no(no:int):
    print('findfabonci_no')
    return str(call_fun(no))

basic_agent = Agent(name='basic_agent',tools=[find_fabonci_no], instructions='you are helpful assistant always call find_fabonci_no function ',model=model ,tool_use_behavior='stop_on_first_tool'                   )

resp =Runner.run(basic_agent,input='we want to calculate fabonichi no of 10')
