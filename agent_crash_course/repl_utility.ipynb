# %%
import nest_asyncio

nest_asyncio.apply()
# 1. AGENT LEVEL
import os
from agents import Agent, OpenAIChatCompletionsModel, AsyncOpenAI, Runner
import asyncio
try:

    GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")
    if not GEMINI_API_KEY:
        raise ValueError("GEMINI ApI key not found")
  
    external_client = AsyncOpenAI(
        base_url="https://generativelanguage.googleapis.com/v1beta/openai/",
        api_key=GEMINI_API_KEY,
    )
    model = OpenAIChatCompletionsModel(
        model="gemini-2.0-flash", openai_client=external_client
    )
except Exception as e:
    print("Error", e)

# %%
import asyncio
from agents import Agent, run_demo_loop

async def main() -> None:
    agent = Agent(name="Assistant", instructions="You are a helpful assistant.",model=model)
    await run_demo_loop(agent)

if __name__ == "__main__":
    asyncio.run(main())
# Out:
# [Agent updated: Assistant]
# Hi there! How can I help you today?
# OPENAI_API_KEY is not set, skipping trace export
# [Agent updated: Assistant]
# AI, or Artificial Intelligence, is a broad field of computer science focused on creating machines that can perform tasks that typically require human intelligence. Think of it as making computers "smart" enough to do things like:
#
# *   **Learning:** Acquiring information and rules for using the information.
# *   **Reasoning:** Using rules to reach conclusions (either exact or approximate).
# *   **Problem-solving:** Using reasoning and creativity to solve problems.
# *   **Perception:** Using
# OPENAI_API_KEY is not set, skipping trace export
#  senses (like seeing, hearing, or reading) to understand the world around them.
# *   **Natural Language Processing (NLP):** Understanding and generating human language.
#
# **Here's a breakdown of some key aspects of AI:**
#
# *   **Goal:** To develop computer systems that can mimic human cognitive abilities.
# *   **Methods:** AI uses various methods including machine learning, deep learning, rule-based systems, and more.
# *   **Applications:** AI is used in a wide range of applications, from self-driving cars and medical diagnosis to virtual assistants and fraud detection.
#
# **Think of AI in levels of sophistication:**
#
# *   **Narrow or Weak AI:** Designed for a specific task (like playing chess or recommending products).  This is what most AI applications are today.
# *   **General or Strong AI:** Hypothetical AI with the ability to understand, learn, and apply knowledge across a wide range of tasks, much like a human.  This doesn't exist yet.
# *   **Super AI:** Hypothetical AI that surpasses human intelligence in all aspects.  This is purely theoretical.
#
# **In simpler terms:**
#
# Imagine teaching a computer to recognize cats in pictures.  Instead of manually programming it with rules like "cats have pointed ears and whiskers," you could show it thousands of pictures of cats and let it learn the patterns on its own. That's AI in action.
#
# Do you want to delve deeper into any specific aspect of AI, such as Machine Learning or its applications? I can provide more details.
# OPENAI_API_KEY is not set, skipping trace export
