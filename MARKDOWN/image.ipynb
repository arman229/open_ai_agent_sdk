# %% [markdown]
# [![image is not shows](download.jpeg)](https://github.com/panaversity/learn-agentic-ai/tree/main/01_ai_agents_first/04_hello_agent)

# %% [markdown]
# # Clickable OpenAI Logo
#
# [![OpenAI](<download.jpeg>)](https://openai.com)

# %% [markdown]
# ![Alt text](download.jpeg "Title with "quotes"")
#
# ![Alt text](download.jpeg 'Title with "quotes"')
#
# ![Alt text](download.jpeg "Title with \"quotes\"")
#
# ![Alt text](download.jpeg "Title with &quot;quotes&quot;")

# %% [markdown]
# ![Alt text](download.jpeg "Title with \"quotes\"")
# ![Alt text](./download.jpeg "Title with \"quotes\"")
# ![Alt [text]f d ](./download.jpeg "Title with \"quotes\"")

# %% [markdown]
# ![Alt text]()

# %% [markdown]
# <img src="download.jpeg" alt="Alt text" width="300">
# <img src="download.jpeg" alt="Alt text" {width="300"}>

# %% [markdown]
# ![Alt text](<download.jpeg>)
# ![Alt text][ref]
#
# [ref]: download.jpeg

# %% [markdown]
# ![Alt text][]
# ![Alt text][Alt text]
#
# [Alt text]: download.jpeg

# %% [markdown]
# ![Alt text][hi]
#
# [hi]: download.jpeg
