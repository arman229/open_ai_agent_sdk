# %% [markdown]
# [Link](https://github.com/panaversity/learn-agentic-ai/tree/main/01_ai_agents_first/04_hello_agent)

# %% [markdown]
# <https://github.com/panaversity/learn-agentic-ai/tree/main/01_ai_agents_first/04_hello_agent>

# %% [markdown]
# https://github.com/panaversity/learn-agentic-ai/tree/main/01_ai_agents_first/04_hello_agent

# %% [markdown]
# <mailto:armanashraf015@gmail.com>
